# %%
import pandas as pd
import numpy as np

# %%
anime_movies = pd.read_csv("C:\\Users\\VALUEDSEED\\Downloads\\archive (1)\\top_100_anime_movie.csv")

# %%
anime_movies #to drop an entire cells and missing figures in a column
# Out:
#     rank                                              title  rating    votes  \
# 0      1                Ramayana: The Legend of Prince Rama     9.2    7,549
# 1      2                                      Spirited Away     8.6  756,112
# 2      3      Meiji Tokyo Renka Movie: Yumihari no Serenade     8.5       39
# 3      4             Natsu e no tunnel, Sayonara no deguchi     8.5       23
# 4      5                         Attack on Titan: Chronicle     8.5   10,421
# ..   ...                                                ...     ...      ...
# 95    96  Mobile Suit Gundam: The Origin IV - Eve of Des...     7.7      462
# 96    97                            Dou Kyu Sei: Classmates     7.7    2,742
# 97    98         The Shimajiro Movie: Shimajiro in Bookland     7.7       25
# 98    99                                     In This Corner     7.7   11,242
# 99   100                                       Asatte Dansu     7.7       10
#
# ...

# %%
anime_movies.drop(columns = ["gross"]) #entire columns
# Out:
#     rank                                              title  rating    votes  \
# 1      2                                      Spirited Away     8.6  756,112
# 8      9                                         Your Name.     8.4  265,332
# 9     10                                  Princess Mononoke     8.4  392,732
# 18    19                Demon Slayer the Movie: Mugen Train     8.2   57,328
# 20    21                               Howl's Moving Castle     8.2  393,001
# 29    30                                 My Neighbor Totoro     8.1  337,655
# 32    33                        I Want to Eat Your Pancreas     8.0   17,152
# 38    39                    The Tale of The Princess Kaguya     8.0   47,044
# 40    41  Puella Magi Madoka Magica the Movie Part 2: Et...     8.0    1,530
# 48    49                                       Perfect Blue     8.0   76,780
# 49    50                                              Akira     8.0  186,597
# ...

# %%
anime_movies.dropna()
# Out:
#     rank                                              title  rating    votes  \
# 1      2                                      Spirited Away     8.6  756,112
# 8      9                                         Your Name.     8.4  265,332
# 9     10                                  Princess Mononoke     8.4  392,732
# 18    19                Demon Slayer the Movie: Mugen Train     8.2   57,328
# 20    21                               Howl's Moving Castle     8.2  393,001
# 29    30                                 My Neighbor Totoro     8.1  337,655
# 32    33                        I Want to Eat Your Pancreas     8.0   17,152
# 38    39                    The Tale of The Princess Kaguya     8.0   47,044
# 40    41  Puella Magi Madoka Magica the Movie Part 2: Et...     8.0    1,530
# 48    49                                       Perfect Blue     8.0   76,780
# 49    50                                              Akira     8.0  186,597
# ...

# %%
anime_movies.dropna(axis = 0, how = "any", inplace = True)

# %%
anime_movies
# Out:
#     rank                                              title  rating    votes  \
# 1      2                                      Spirited Away     8.6  756,112
# 8      9                                         Your Name.     8.4  265,332
# 9     10                                  Princess Mononoke     8.4  392,732
# 18    19                Demon Slayer the Movie: Mugen Train     8.2   57,328
# 20    21                               Howl's Moving Castle     8.2  393,001
# 29    30                                 My Neighbor Totoro     8.1  337,655
# 32    33                        I Want to Eat Your Pancreas     8.0   17,152
# 38    39                    The Tale of The Princess Kaguya     8.0   47,044
# 40    41  Puella Magi Madoka Magica the Movie Part 2: Et...     8.0    1,530
# 48    49                                       Perfect Blue     8.0   76,780
# 49    50                                              Akira     8.0  186,597
# ...

# %%
anime_movies.isnull().sum()
# Out:
# rank       0
# title      0
# rating     0
# votes      0
# year       0
# minutes    0
# genre      0
# gross      0
# dtype: int64

# %%
anime_movies = pd.read_csv("C:\\Users\\VALUEDSEED\\Downloads\\archive (1)\\top_100_anime_movie.csv")

# %%
anime_movies #replacing missing figure
#using function (fillna)
# Out:
#     rank                                              title  rating    votes  \
# 0      1                Ramayana: The Legend of Prince Rama     9.2    7,549
# 1      2                                      Spirited Away     8.6  756,112
# 2      3      Meiji Tokyo Renka Movie: Yumihari no Serenade     8.5       39
# 3      4             Natsu e no tunnel, Sayonara no deguchi     8.5       23
# 4      5                         Attack on Titan: Chronicle     8.5   10,421
# ..   ...                                                ...     ...      ...
# 95    96  Mobile Suit Gundam: The Origin IV - Eve of Des...     7.7      462
# 96    97                            Dou Kyu Sei: Classmates     7.7    2,742
# 97    98         The Shimajiro Movie: Shimajiro in Bookland     7.7       25
# 98    99                                     In This Corner     7.7   11,242
# 99   100                                       Asatte Dansu     7.7       10
#
# ...

# %%
anime_movies.isnull().sum()
# Out:
# rank        0
# title       0
# rating      0
# votes       0
# year        0
# minutes     4
# genre       0
# gross      80
# dtype: int64

# %%
anime_movies["minutes"].fillna(anime_movies["minutes"].mean(), inplace = True)

# %%
anime_movies
# Out:
#     rank                                              title  rating    votes  \
# 0      1                Ramayana: The Legend of Prince Rama     9.2    7,549
# 1      2                                      Spirited Away     8.6  756,112
# 2      3      Meiji Tokyo Renka Movie: Yumihari no Serenade     8.5       39
# 3      4             Natsu e no tunnel, Sayonara no deguchi     8.5       23
# 4      5                         Attack on Titan: Chronicle     8.5   10,421
# ..   ...                                                ...     ...      ...
# 95    96  Mobile Suit Gundam: The Origin IV - Eve of Des...     7.7      462
# 96    97                            Dou Kyu Sei: Classmates     7.7    2,742
# 97    98         The Shimajiro Movie: Shimajiro in Bookland     7.7       25
# 98    99                                     In This Corner     7.7   11,242
# 99   100                                       Asatte Dansu     7.7       10
#
# ...

# %%
anime_movies.isnull().sum()
# Out:
# rank        0
# title       0
# rating      0
# votes       0
# year        0
# minutes     0
# genre       0
# gross      80
# dtype: int64

# %%
tested = pd.read_csv("C:\\Users\\VALUEDSEED\\Downloads\\tested.csv")

# %%
tested
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
tested.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
tested["Age"].fillna(tested["Age"].median(), inplace = True)

# %%
tested
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
tested.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
tested.drop(columns = ["Cabin"], inplace = True)

# %%
tested["Fare"].fillna(tested["Fare"].mean(), inplace = True)

# %%
tested
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
tested.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
tested.to_csv("C:\\Users\VALUEDSEED\\Desktop\\All\\Scanned Items\\tested.csv")

# %%
tested.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          418 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         418 non-null    float64
#  10  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(4)
# memory usage: 36.0+ KB

# %%
from sklearn.preprocessing import LabelEncoder

tech = LabelEncoder()

# %%
clubs = pd.DataFrame({'Club name': ['Bayern Munich', 'Barcelona', 'Chelsea', 'Liverpool', 'Manchester City', 'Ajax', 'Eyimba', 'Kano pillars'],
                      'League': ['German League', 'Spanish League', None , 'English Premier League', 'English Premier League', 'Dutch League',
                                'Nigerian League', 'Nigerian League'],
                     'No of League Titles': [10, 8, 3, 4, 5, 10, 3, 2]})

clubs
# Out:
#          Club name                  League  No of League Titles
# 0    Bayern Munich           German League                   10
# 1        Barcelona          Spanish League                    8
# 2          Chelsea                    None                    3
# 3        Liverpool  English Premier League                    4
# 4  Manchester City  English Premier League                    5
# 5             Ajax            Dutch League                   10
# 6           Eyimba         Nigerian League                    3
# 7     Kano pillars         Nigerian League                    2

# %%
clubs["League"].fillna("English Premier League", inplace = True)

# %%
clubs
# Out:
#          Club name                  League  No of League Titles
# 0    Bayern Munich           German League                   10
# 1        Barcelona          Spanish League                    8
# 2          Chelsea  English Premier League                    3
# 3        Liverpool  English Premier League                    4
# 4  Manchester City  English Premier League                    5
# 5             Ajax            Dutch League                   10
# 6           Eyimba         Nigerian League                    3
# 7     Kano pillars         Nigerian League                    2

# %%
from sklearn.preprocessing import LabelEncoder
den = LabelEncoder()

# %%
clubs["league_category_2"] = den.fit_transform(clubs["League"])

clubs
# Out:
#          Club name                  League  No of League Titles  \
# 0    Bayern Munich           German League                   10
# 1        Barcelona          Spanish League                    8
# 2          Chelsea  English Premier League                    3
# 3        Liverpool  English Premier League                    4
# 4  Manchester City  English Premier League                    5
# 5             Ajax            Dutch League                   10
# 6           Eyimba         Nigerian League                    3
# 7     Kano pillars         Nigerian League                    2
#
#    league_category_2
# 0                  2
# 1                  4
# 2                  1
# 3                  1
# 4                  1
# 5                  0
# 6                  3
# 7                  3

# %%
del LabelEncoder
